# %% [markdown]
# ---
#
#
# # Just Enough Python for Data Analysis
# >
#
# ##                                    -By Rituraj Dixit
#
#
# ---

# %% [markdown]
# ## Introduction to Python
#
# This notebook provides a basic introduction to Python programming language.
#
# - [Notebook for Inroduction to Python](https://drive.google.com/file/d/1l16nTkWuRnXWMhQqsORzrn2QrzQVu-aN/view?usp=drive_link)
#
# ## Working with Built-in Data Types of Python
#
# This notebook covers the hands-on examples to understand the built in Data Types in Python.
#
# - [Notebook for Built-in Data Types in Python](https://drive.google.com/file/d/1nrA5ZbfcGswrHWMaqARXCUbz9W0UWmEV/view?usp=drive_link)
#
# ## Working with Conditional Statements in Python
#
# This notebook covers the hands-on examples to understand how to write Conditional Statements in Python?
#
# - [Notebook for Conditional Statements in Python](https://drive.google.com/file/d/1GruQ9oMqsMbHJYKVGKlmgyioFsAm9bmv/view?usp=drive_link)
#
# ## Working with User defined function in Python
#
# This notebook covers the hands-on examples to understand how to write user defined functions and use them in Python.
#
# - [Notebook for Function in Python](https://drive.google.com/file/d/1XvzXdrB3Ux4xWmEXX1VwFAJDjqKnZZm_/view?usp=drive_link)
#
# ## Working with Loops in Python
#
# This notebook covers the hands-on examples to understand workign with Loops and loop controls in Python.
#
# - [Notebook for Loops in Python](https://drive.google.com/file/d/1--bXmHFe5vvisMAz2sAUUT0-CEptbfW6/view?usp=drive_link)
#
# ## Working with Fie I/O
#
# This notebook covers the hands-on examples to understand reading and writing the files in Python.
#
# - [ Notebook for File Handling in Python](https://drive.google.com/file/d/1-3ABVG0npCakC2NHfr84rKBU5FcJHhQO/view?usp=drive_link)
